# %%
import yfinance as yf

# List of 30 sample equity tickers
tickers = [
    "AAPL", "MSFT", "GOOG", "AMZN", "FB", "TSLA", "BRK-A", "JPM", "JNJ", "V",
    "PG", "UNH", "HD", "MA", "VZ", "NVDA", "PYPL", "DIS", "ADBE", "NFLX",
    "CMCSA", "CSCO", "PEP", "KO", "MRK", "PFE", "TM", "BABA", "XOM", "WMT"
]

equity_data = {}
for ticker in tickers:
    try:
        # Fetch historical data (closing prices)
        data = yf.download(ticker, period="max")['Close']
        equity_data[ticker] = data
        print(f"Successfully fetched data for {ticker}")
    except Exception as e:
        print(f"Could not fetch data for {ticker}: {e}")

# You can now access the time series data for each equity using the dictionary:
# For example, to see the data for AAPL:
# print(equity_data["AAPL"].head())
# Out:
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for AAPL
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for MSFT
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for GOOG
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for AMZN
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for FB
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for TSLA
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for BRK-A
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for JPM
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for JNJ
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for V
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for PG
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for UNH
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for HD
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for MA
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for VZ
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for NVDA
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for PYPL
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for DIS
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for ADBE
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for NFLX
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for CMCSA
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for CSCO
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for PEP
# [*********************100%***********************]  1 of 1 completed
# Successfully fetched data for KO
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for MRK
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for PFE
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for TM
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for BABA
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-616332059.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="max")['Close']
# Successfully fetched data for XOM
# [*********************100%***********************]  1 of 1 completed
# Successfully fetched data for WMT

# %%
for d,v in equity_data.items():
  print(d,len(v))
# Out:
# AAPL 11266
# MSFT 9940
# GOOG 5288
# AMZN 7114
# FB 42
# TSLA 3813
# BRK-A 11454
# JPM 11454
# JNJ 16019
# V 4387
# PG 16019
# UNH 10293
# HD 11071
# MA 4843
# VZ 10522
# NVDA 6689
# PYPL 2551
# DIS 16019
# ADBE 9834
# NFLX 5852
# CMCSA 11454
# CSCO 8945
# PEP 13420
# KO 16019
# MRK 16019
# PFE 13420
# TM 11454
# BABA 2749
# XOM 16019
# WMT 13360

# %%
equity_data["AAPL"]
# Out:
# Ticker            AAPL
# Date
# 1980-12-12    0.098485
# 1980-12-15    0.093347
# 1980-12-16    0.086495
# 1980-12-17    0.088636
# 1980-12-18    0.091206
# ...                ...
# 2025-08-19  230.559998
# 2025-08-20  226.009995
# 2025-08-21  224.899994
# 2025-08-22  227.759995
# 2025-08-25  227.160004
#
# [11266 rows x 1 columns]

# %%
1 or np.nan
# Out:
# 1

# %%
import pandas as pd

# Find the earliest start date among all time series
earliest_start_date = min(series.index[0] for series in equity_data.values())
most_recent_date = max(series.index[-1] for series in equity_data.values())
# Pad each time series with zeros backwards to the earliest start date
#padded_equity_data = {}
for ticker, series in equity_data.items():
    # Create a new series with zeros for the missing dates
    new_index = pd.date_range(start=earliest_start_date, end=most_recent_date, freq='B')
    series.reindex(new_index,fill_value=0.0)

# Verify that all series start at the same date
for ticker, series in padded_equity_data.items():
    print(f"{ticker}: {series.index[0]} : {len(series)} : {series.shape}")
# Out:
# AAPL: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# MSFT: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# GOOG: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# AMZN: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# FB: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# TSLA: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# BRK-A: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# JPM: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# JNJ: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# V: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# PG: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# UNH: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# HD: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# MA: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# VZ: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# NVDA: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# PYPL: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# DIS: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# ADBE: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# NFLX: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# CMCSA: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# CSCO: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# PEP: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# KO: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# MRK: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# PFE: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# TM: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# BABA: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# XOM: 1962-01-02 00:00:00 : 16605 : (16605, 1)
# WMT: 1962-01-02 00:00:00 : 16605 : (16605, 1)

# %%
equity_data['WMT'].shape
# Out:
# (16605, 1)

# %%
import math
import random
from dataclasses import dataclass
from typing import Dict, Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# Helpers: Sharpe & utilities
# -----------------------------

def compute_daily_returns(prices: pd.Series) -> pd.Series:
    # Calculate percentage change and fill NaN values (first row) with 0
    returns = prices.pct_change().fillna(0.0)
    # Replace infinite values (resulting from division by zero due to padding) with 0
    returns = returns.replace([np.inf, -np.inf], 0.0)
    return returns

def annualized_sharpe(returns: pd.Series, risk_free_daily: float = 0.0, trading_days: int = 252) -> float:
    excess = returns - risk_free_daily
    mu = excess.mean()
    sigma = excess.std(ddof=0)
    if sigma == 0:
        return 0.0
    return (mu / sigma) * math.sqrt(trading_days)

def equity_curve_from_returns(returns: pd.Series, start_value: float = 1.0) -> pd.Series:
    return start_value * (1.0 + returns).cumprod()

# -----------------------------
# Simple SMA Strategy (baseline)
# -----------------------------

def sma_strategy(prices: pd.Series, fast: int = 20, slow: int = 50) -> pd.Series:
    fast_ma = prices.rolling(fast).mean()
    slow_ma = prices.rolling(slow).mean()
    signal = np.sign(fast_ma - slow_ma).fillna(0.0)
    rets = compute_daily_returns(prices)
    strat_rets = signal.shift(1).fillna(0.0) * rets
    strat_rets.name = "SMA_returns"
    return strat_rets

# ----------------------------------------
# RL Environment (single asset, discrete)
# ----------------------------------------

@dataclass
class EnvConfig:
    window: int = 30
    trans_cost: float = 0.0002
    risk_aversion: float = 5.0
    max_position: int = 1
    trading_days: int = 252

class SingleAssetTradingEnv:
    def __init__(self, prices: pd.Series, cfg: EnvConfig):
        self.prices = prices.dropna().copy()
        # Ensure returns is a Series for compute_daily_returns
        if isinstance(self.prices, pd.DataFrame):
             self.returns = compute_daily_returns(self.prices.iloc[:, 0]).values # Take the first column if DataFrame
        else:
             self.returns = compute_daily_returns(self.prices).values
        self.cfg = cfg
        self.T = len(self.returns)
        self.reset()


    def reset(self) -> np.ndarray:
        self.t = self.cfg.window
        self.position = 0
        return self._get_state()

    def _get_state(self) -> np.ndarray:
        window_ret = self.returns[self.t - self.cfg.window:self.t]
        pos_oh = np.zeros(3)
        pos_oh[self.position + 1] = 1.0
        return np.concatenate([window_ret.flatten(), pos_oh]) # Flatten window_ret to ensure 1D


    def step(self, action: int) -> Tuple[np.ndarray, float, bool, dict]:
        new_position = action - 1
        new_position = int(np.clip(new_position, -self.cfg.max_position, self.cfg.max_position))
        r_t = self.returns[self.t]
        pnl = self.position * r_t # profit and loss
        cost = self.cfg.trans_cost * abs(new_position - self.position)
        reward = pnl - cost - self.cfg.risk_aversion * (pnl ** 2)

        self.position = new_position
        self.t += 1
        done = self.t >= self.T - 1
        state = self._get_state() if not done else None
        info = {"pnl": pnl, "cost": cost, "raw_ret": r_t, "position": self.position}
        return state, float(reward), bool(done), info

# ----------------------------------------
# DQN (NumPy) with Experience Replay
# ----------------------------------------

@dataclass
class DQNConfig:
    state_dim: int
    action_dim: int = 3
    hidden_dim: int = 64
    gamma: float = 0.99
    lr: float = 1e-3
    batch_size: int = 64
    buffer_size: int = 20000
    min_buffer: int = 512
    epsilon_start: float = 1.0
    epsilon_end: float = 0.05
    epsilon_decay_steps: int = 5000
    target_update_every: int = 200
    train_steps: int = 15000
    seed: int = 42

class ReplayBuffer:
    def __init__(self, capacity: int, state_dim: int):
        self.capacity = capacity
        self.s = np.zeros((capacity, state_dim), dtype=np.float32)
        self.a = np.zeros((capacity,), dtype=np.int64)
        self.r = np.zeros((capacity,), dtype=np.float32)
        self.ns = np.zeros((capacity, state_dim), dtype=np.float32)
        self.d = np.zeros((capacity,), dtype=np.float32)
        self.ptr = 0
        self.size = 0

    def add(self, s, a, r, ns, d):
        self.s[self.ptr] = s
        self.a[self.ptr] = a
        self.r[self.ptr] = r
        self.ns[self.ptr] = ns if ns is not None else 0.0
        self.d[self.ptr] = d
        self.ptr = (self.ptr + 1) % self.capacity
        self.size = min(self.size + 1, self.capacity)

    def sample(self, batch_size):
        idx = np.random.randint(0, self.size, size=batch_size)
        return (self.s[idx], self.a[idx], self.r[idx], self.ns[idx], self.d[idx])

def xavier_init(in_dim, out_dim):
    limit = math.sqrt(6 / (in_dim + out_dim))
    return np.random.uniform(-limit, limit, (in_dim, out_dim)).astype(np.float32), np.zeros((out_dim,), dtype=np.float32)

class Dense:
    def __init__(self, in_dim, out_dim):
        W, b = xavier_init(in_dim, out_dim)
        self.W = W
        self.b = b
        self.dW = np.zeros_like(W)
        self.db = np.zeros_like(b)

    def forward(self, x):
        self.x = x
        return x @ self.W + self.b

    def backward(self, grad_out):
        self.dW = self.x.T @ grad_out
        self.db = grad_out.sum(axis=0)
        return grad_out @ self.W.T

    def step(self, lr):
        self.W -= lr * self.dW
        self.b -= lr * self.db

class ReLU:
    def forward(self, x):
        self.mask = (x > 0).astype(np.float32)
        return x * self.mask
    def backward(self, grad_out):
        return grad_out * self.mask

class QNetwork:
    def __init__(self, state_dim, hidden_dim, action_dim):
        self.l1 = Dense(state_dim, hidden_dim)
        self.act1 = ReLU()
        self.l2 = Dense(hidden_dim, hidden_dim)
        self.act2 = ReLU()
        self.out = Dense(hidden_dim, action_dim)

    def forward(self, x):
        z1 = self.l1.forward(x)
        a1 = self.act1.forward(z1)
        z2 = self.l2.forward(a1)
        a2 = self.act2.forward(z2)
        q = self.out.forward(a2)
        return q

    def backward(self, grad_q):
        grad = self.out.backward(grad_q)
        grad = self.act2.backward(grad)
        grad = self.l2.backward(grad)
        grad = self.act1.backward(grad)
        grad = self.l1.backward(grad)

    def step(self, lr):
        for layer in [self.l1, self.l2, self.out]:
            layer.step(lr)

    def copy_from(self, other: "QNetwork"):
        for (s, o) in [(self.l1, other.l1), (self.l2, other.l2), (self.out, other.out)]:
            s.W[:] = o.W
            s.b[:] = o.b

class DQNAgent:
    def __init__(self, cfg: DQNConfig):
        np.random.seed(cfg.seed)
        random.seed(cfg.seed)
        self.cfg = cfg
        self.q = QNetwork(cfg.state_dim, cfg.hidden_dim, cfg.action_dim)
        self.target = QNetwork(cfg.state_dim, cfg.hidden_dim, cfg.action_dim)
        self.target.copy_from(self.q)
        self.buffer = ReplayBuffer(cfg.buffer_size, cfg.state_dim)
        self.train_step = 0

    def epsilon(self):
        t = min(self.train_step, self.cfg.epsilon_decay_steps)
        frac = 1.0 - t / self.cfg.epsilon_decay_steps
        return self.cfg.epsilon_end + (self.cfg.epsilon_start - self.cfg.epsilon_end) * max(frac, 0.0)

    def act(self, state: np.ndarray) -> int:
        if np.random.rand() < self.epsilon():
            return np.random.randint(self.cfg.action_dim)
        q = self.q.forward(state[None, :])
        return int(np.argmax(q[0]))

    def learn(self):
        if self.buffer.size < self.cfg.min_buffer:
            return
        s, a, r, ns, d = self.buffer.sample(self.cfg.batch_size)
        q = self.q.forward(s)
        q_a = q[np.arange(self.cfg.batch_size), a]

        next_q = self.q.forward(ns)
        next_actions = np.argmax(next_q, axis=1)
        target_q = self.target.forward(ns)
        target_next = target_q[np.arange(self.cfg.batch_size), next_actions]

        y = r + (1 - d) * self.cfg.gamma * target_next

        grad_q = np.zeros_like(q)
        grad_q[np.arange(self.cfg.batch_size), a] = (q_a - y) / self.cfg.batch_size

        self.q.backward(grad_q)
        self.q.step(self.cfg.lr)

        self.train_step += 1
        if self.train_step % self.cfg.target_update_every == 0:
            self.target.copy_from(self.q)

    def fit_env(self, env: SingleAssetTradingEnv):
        s = env.reset()
        for _ in range(self.cfg.min_buffer):
            a = np.random.randint(self.cfg.action_dim)
            ns, r, done, _ = env.step(a)
            self.buffer.add(s, a, r, ns if not done else s, float(done))
            s = env.reset() if done else ns

        s = env.reset()
        for _ in range(self.cfg.train_steps):
            a = self.act(s)
            ns, r, done, _ = env.step(a)
            self.buffer.add(s, a, r, ns if not done else s, float(done))
            self.learn()
            s = env.reset() if done else ns

# -----------------------------
# Backtest Utilities
# -----------------------------

def equal_weight_portfolio(returns_dict: Dict[str, pd.Series]) -> pd.Series:
    aligned = pd.concat(returns_dict.values(), axis=1).dropna(how="all")
    aligned = aligned.fillna(0.0)
    ew = aligned.mean(axis=1)
    ew.name = "Portfolio_returns"
    return ew

# -----------------------------
# CONFIG + Example Data
# -----------------------------

WINDOW = 30
ENV_CFG = EnvConfig(window=WINDOW, trans_cost=0.0002, risk_aversion=5.0, max_position=1)

DQN_BASE = {
    "action_dim": 3,
    "hidden_dim": 64,
    "gamma": 0.99,
    "lr": 1e-3,
    "batch_size": 64,
    "buffer_size": 20000,
    "min_buffer": 512,
    "epsilon_start": 1.0,
    "epsilon_end": 0.05,
    "epsilon_decay_steps": 5000,
    "target_update_every": 200,
    "train_steps": 6000,
    "seed": 42,
}

# Example synthetic data
np.random.seed(7)
dates = pd.bdate_range("2020-01-01", "2023-12-29")
def make_price(mu=0.0003, sigma=0.02, start=100.0):
    rets = np.random.normal(mu, sigma, len(dates))
    price = start * np.cumprod(1 + rets)
    return pd.Series(price, index=dates)

price_series_dict = {
    "ASSET_A": make_price(mu=0.0004, sigma=0.018, start=100),
    "ASSET_B": make_price(mu=0.0002, sigma=0.022, start=50),
    "ASSET_C": make_price(mu=0.00025, sigma=0.019, start=200),
}

price_series_dict = equity_data # Use the fetched equity data


split_date = "2025-01-01"
train_prices = {k: v.loc[:split_date] for k, v in price_series_dict.items()}
test_prices  = {k: v.loc[split_date:] for k, v in price_series_dict.items()}

# ----------------------------------------
# Train + Backtest
# ----------------------------------------

rl_returns_dict = {}
sma_returns_dict = {}

for ticker, px in train_prices.items():
    state_dim = ENV_CFG.window + 3
    dqn_cfg = DQNConfig(state_dim=state_dim, **DQN_BASE)

    env_train = SingleAssetTradingEnv(px, ENV_CFG)
    agent = DQNAgent(dqn_cfg)
    agent.fit_env(env_train)

    env_test = SingleAssetTradingEnv(test_prices[ticker], ENV_CFG)
    s = env_test.reset()
    pnl_series = []
    for t in range(ENV_CFG.window, len(env_test.returns) - 1):
        a = agent.act(s)
        ns, r, done, info = env_test.step(a)
        pnl_series.append(info["pnl"])
        if done: break
        s = ns

    idx = test_prices[ticker].index[ENV_CFG.window:ENV_CFG.window + len(pnl_series)]
    rl_returns_dict[ticker] = pd.Series(pnl_series, index=idx, name=f"{ticker}_RL")

    sma_ret = sma_strategy(test_prices[ticker].iloc[:, 0] if isinstance(test_prices[ticker], pd.DataFrame) else test_prices[ticker], fast=20, slow=50).loc[idx] # Handle potential DataFrame input
    sma_returns_dict[ticker] = sma_ret.rename(f"{ticker}_SMA")

rl_portfolio = equal_weight_portfolio(rl_returns_dict)
sma_portfolio = equal_weight_portfolio(sma_returns_dict)

rl_sharpe = annualized_sharpe(rl_portfolio)
sma_sharpe = annualized_sharpe(sma_portfolio)

rl_equity = equity_curve_from_returns(rl_portfolio, 1.0)
sma_equity = equity_curve_from_returns(sma_portfolio, 1.0)

print("=== Portfolio Performance (Out-of-sample) ===")
print(f"RL (DQN) Annualized Sharpe: {rl_sharpe:.3f}")
print(f"SMA (20/50) Annualized Sharpe: {sma_sharpe:.3f}")

plt.figure(figsize=(10, 5))
plt.plot(rl_equity.index, rl_equity.values, label="RL (DQN)")
plt.plot(sma_equity.index, sma_equity.values, label="SMA 20/50")
plt.title("Equity Curve (Equal-Weight Portfolio)")
plt.legend()
plt.savefig("exemplo.png")
# Out:
# === Portfolio Performance (Out-of-sample) ===
# RL (DQN) Annualized Sharpe: 1.573
# SMA (20/50) Annualized Sharpe: -0.557

# %%
price_series_dict
# Out:
# {'ASSET_A': 2020-01-01    103.082946
#  2020-01-02    102.259636
#  2020-01-03    102.360951
#  2020-01-06    103.152743
#  2020-01-07    101.729172
#                   ...
#  2023-12-25     88.661039
#  2023-12-26     87.462754
#  2023-12-27     86.780595
#  2023-12-28     84.740212
#  2023-12-29     83.987102
#  Freq: B, Length: 1043, dtype: float64,
#  'ASSET_B': 2020-01-01    50.078424
#  2020-01-02    48.444125
#  2020-01-03    47.505099
#  2020-01-06    47.433815
#  2020-01-07    46.132362
#                  ...
#  2023-12-25    12.594029
#  2023-12-26    12.004458
#  2023-12-27    11.898306
#  2023-12-28    12.511638
#  2023-12-29    12.571211
#  Freq: B, Length: 1043, dtype: float64,
#  'ASSET_C': 2020-01-01    195.409874
#  2020-01-02    196.683574
#  2020-01-03    195.572694
#  2020-01-06    196.226555
#  2020-01-07    194.562791
#                   ...
#  2023-12-25    290.500187
#  2023-12-26    283.159842
#  2023-12-27    278.109268
#  2023-12-28    277.425787
#  2023-12-29    282.921672
#  Freq: B, Length: 1043, dtype: float64}

# %%
equity_data
# Out:
# {'AAPL': Ticker            AAPL
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  230.559998
#  2025-08-20  226.009995
#  2025-08-21  224.899994
#  2025-08-22  227.759995
#  2025-08-25  227.160004
#
#  [16605 rows x 1 columns],
#  'MSFT': Ticker            MSFT
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  508.933350
#  2025-08-20  504.890015
#  2025-08-21  504.239990
#  2025-08-22  507.230011
#  2025-08-25  504.260010
#
#  [16605 rows x 1 columns],
#  'GOOG': Ticker            GOOG
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  202.490005
#  2025-08-20  200.190002
#  2025-08-21  200.619995
#  2025-08-22  206.720001
#  2025-08-25  209.160004
#
#  [16605 rows x 1 columns],
#  'AMZN': Ticker            AMZN
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  228.009995
#  2025-08-20  223.809998
#  2025-08-21  221.949997
#  2025-08-22  228.839996
#  2025-08-25  227.940002
#
#  [16605 rows x 1 columns],
#  'FB': Ticker             FB
#  1962-01-02   0.000000
#  1962-01-03   0.000000
#  1962-01-04   0.000000
#  1962-01-05   0.000000
#  1962-01-08   0.000000
#  ...               ...
#  2025-08-19  40.776001
#  2025-08-20  40.726002
#  2025-08-21  40.599998
#  2025-08-22  40.875999
#  2025-08-25  40.889999
#
#  [16605 rows x 1 columns],
#  'TSLA': Ticker            TSLA
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  329.309998
#  2025-08-20  323.899994
#  2025-08-21  320.109985
#  2025-08-22  340.010010
#  2025-08-25  346.600006
#
#  [16605 rows x 1 columns],
#  'BRK-A': Ticker         BRK-A
#  1962-01-02       0.0
#  1962-01-03       0.0
#  1962-01-04       0.0
#  1962-01-05       0.0
#  1962-01-08       0.0
#  ...              ...
#  2025-08-19  727200.0
#  2025-08-20  732814.0
#  2025-08-21  733080.0
#  2025-08-22  734405.0
#  2025-08-25  729687.0
#
#  [16605 rows x 1 columns],
#  'JPM': Ticker             JPM
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  290.660004
#  2025-08-20  292.239990
#  2025-08-21  291.470001
#  2025-08-22  296.239990
#  2025-08-25  294.899994
#
#  [16605 rows x 1 columns],
#  'JNJ': Ticker             JNJ
#  1962-01-02    0.061495
#  1962-01-03    0.060539
#  1962-01-04    0.059902
#  1962-01-05    0.058946
#  1962-01-08    0.057990
#  ...                ...
#  2025-08-19  177.800003
#  2025-08-20  178.839996
#  2025-08-21  178.929993
#  2025-08-22  179.289993
#  2025-08-25  178.410004
#
#  [16605 rows x 1 columns],
#  'V': Ticker               V
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  342.450012
#  2025-08-20  343.929993
#  2025-08-21  343.690002
#  2025-08-22  350.040009
#  2025-08-25  348.820007
#
#  [16605 rows x 1 columns],
#  'PG': Ticker              PG
#  1962-01-02    0.249784
#  1962-01-03    0.247054
#  1962-01-04    0.242960
#  1962-01-05    0.241253
#  1962-01-08    0.234770
#  ...                ...
#  2025-08-19  158.399994
#  2025-08-20  159.509995
#  2025-08-21  158.729996
#  2025-08-22  158.669998
#  2025-08-25  156.149994
#
#  [16605 rows x 1 columns],
#  'UNH': Ticker             UNH
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  304.239990
#  2025-08-20  299.839996
#  2025-08-21  303.350006
#  2025-08-22  307.420013
#  2025-08-25  304.859985
#
#  [16605 rows x 1 columns],
#  'HD': Ticker              HD
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  407.200012
#  2025-08-20  401.739990
#  2025-08-21  397.700012
#  2025-08-22  412.790009
#  2025-08-25  408.899994
#
#  [16605 rows x 1 columns],
#  'MA': Ticker              MA
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  585.510010
#  2025-08-20  592.679993
#  2025-08-21  591.919983
#  2025-08-22  598.960022
#  2025-08-25  593.210022
#
#  [16605 rows x 1 columns],
#  'VZ': Ticker             VZ
#  1962-01-02   0.000000
#  1962-01-03   0.000000
#  1962-01-04   0.000000
#  1962-01-05   0.000000
#  1962-01-08   0.000000
#  ...               ...
#  2025-08-19  44.939999
#  2025-08-20  45.060001
#  2025-08-21  45.029999
#  2025-08-22  44.439999
#  2025-08-25  44.230000
#
#  [16605 rows x 1 columns],
#  'NVDA': Ticker            NVDA
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  175.639999
#  2025-08-20  175.399994
#  2025-08-21  174.979996
#  2025-08-22  177.990005
#  2025-08-25  179.809998
#
#  [16605 rows x 1 columns],
#  'PYPL': Ticker           PYPL
#  1962-01-02   0.000000
#  1962-01-03   0.000000
#  1962-01-04   0.000000
#  1962-01-05   0.000000
#  1962-01-08   0.000000
#  ...               ...
#  2025-08-19  69.050003
#  2025-08-20  68.080002
#  2025-08-21  67.550003
#  2025-08-22  69.900002
#  2025-08-25  69.480003
#
#  [16605 rows x 1 columns],
#  'DIS': Ticker             DIS
#  1962-01-02    0.057441
#  1962-01-03    0.058212
#  1962-01-04    0.058212
#  1962-01-05    0.058405
#  1962-01-08    0.058212
#  ...                ...
#  2025-08-19  116.269997
#  2025-08-20  117.040001
#  2025-08-21  116.209999
#  2025-08-22  118.860001
#  2025-08-25  117.709999
#
#  [16605 rows x 1 columns],
#  'ADBE': Ticker            ADBE
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  361.029999
#  2025-08-20  353.429993
#  2025-08-21  353.429993
#  2025-08-22  362.089996
#  2025-08-25  363.209991
#
#  [16605 rows x 1 columns],
#  'NFLX': Ticker             NFLX
#  1962-01-02     0.000000
#  1962-01-03     0.000000
#  1962-01-04     0.000000
#  1962-01-05     0.000000
#  1962-01-08     0.000000
#  ...                 ...
#  2025-08-19  1214.150024
#  2025-08-20  1213.859985
#  2025-08-21  1206.209961
#  2025-08-22  1204.650024
#  2025-08-25  1218.069946
#
#  [16605 rows x 1 columns],
#  'CMCSA': Ticker          CMCSA
#  1962-01-02   0.000000
#  1962-01-03   0.000000
#  1962-01-04   0.000000
#  1962-01-05   0.000000
#  1962-01-08   0.000000
#  ...               ...
#  2025-08-19  33.889999
#  2025-08-20  33.290001
#  2025-08-21  33.599998
#  2025-08-22  34.150002
#  2025-08-25  34.009998
#
#  [16605 rows x 1 columns],
#  'CSCO': Ticker           CSCO
#  1962-01-02   0.000000
#  1962-01-03   0.000000
#  1962-01-04   0.000000
#  1962-01-05   0.000000
#  1962-01-08   0.000000
#  ...               ...
#  2025-08-19  66.760002
#  2025-08-20  67.110001
#  2025-08-21  67.019997
#  2025-08-22  67.320000
#  2025-08-25  67.139999
#
#  [16605 rows x 1 columns],
#  'PEP': Ticker             PEP
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  152.160004
#  2025-08-20  150.729996
#  2025-08-21  148.979996
#  2025-08-22  149.639999
#  2025-08-25  148.199997
#
#  [16605 rows x 1 columns],
#  'KO': Ticker             KO
#  1962-01-02   0.045716
#  1962-01-03   0.044698
#  1962-01-04   0.045038
#  1962-01-05   0.044019
#  1962-01-08   0.043566
#  ...               ...
#  2025-08-19  70.129997
#  2025-08-20  70.699997
#  2025-08-21  70.660004
#  2025-08-22  70.129997
#  2025-08-25  68.930000
#
#  [16605 rows x 1 columns],
#  'MRK': Ticker            MRK
#  1962-01-02   0.065403
#  1962-01-03   0.062663
#  1962-01-04   0.062023
#  1962-01-05   0.059922
#  1962-01-08   0.060105
#  ...               ...
#  2025-08-19  84.930000
#  2025-08-20  84.660004
#  2025-08-21  86.080002
#  2025-08-22  87.370003
#  2025-08-25  85.309998
#
#  [16605 rows x 1 columns],
#  'PFE': Ticker            PFE
#  1962-01-02   0.000000
#  1962-01-03   0.000000
#  1962-01-04   0.000000
#  1962-01-05   0.000000
#  1962-01-08   0.000000
#  ...               ...
#  2025-08-19  25.320000
#  2025-08-20  25.379999
#  2025-08-21  25.740000
#  2025-08-22  25.879999
#  2025-08-25  25.139999
#
#  [16605 rows x 1 columns],
#  'TM': Ticker              TM
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  198.600006
#  2025-08-20  199.190002
#  2025-08-21  197.270004
#  2025-08-22  201.369995
#  2025-08-25  198.369995
#
#  [16605 rows x 1 columns],
#  'BABA': Ticker            BABA
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  119.989998
#  2025-08-20  119.489998
#  2025-08-21  118.089996
#  2025-08-22  122.940002
#  2025-08-25  124.349998
#
#  [16605 rows x 1 columns],
#  'XOM': Ticker             XOM
#  1962-01-02    0.090127
#  1962-01-03    0.091465
#  1962-01-04    0.091688
#  1962-01-05    0.089681
#  1962-01-08    0.089457
#  ...                ...
#  2025-08-19  107.419998
#  2025-08-20  108.529999
#  2025-08-21  109.230003
#  2025-08-22  111.279999
#  2025-08-25  111.739998
#
#  [16605 rows x 1 columns],
#  'WMT': Ticker             WMT
#  1962-01-02    0.000000
#  1962-01-03    0.000000
#  1962-01-04    0.000000
#  1962-01-05    0.000000
#  1962-01-08    0.000000
#  ...                ...
#  2025-08-19  101.290001
#  2025-08-20  102.570000
#  2025-08-21   97.959999
#  2025-08-22   96.830002
#  2025-08-25   96.070000
#
#  [16605 rows x 1 columns]}

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# ===== Environment =====
class PortfolioEnv:
    def __init__(self, returns, window=20, cost=0.001):
        self.returns = returns
        self.n_assets = returns.shape[1]
        self.window = window
        self.cost = cost
        self.reset()

    def reset(self):
        self.t = self.window
        self.done = False
        self.weights = np.ones(self.n_assets) / self.n_assets
        self.episode_returns = []
        return self._get_state()

    def step(self, new_weights):
        old_weights = self.weights
        new_weights = np.clip(new_weights, 0, 1)
        new_weights /= (new_weights.sum() + 1e-8)  # normalize

        # turnover cost
        turnover = np.abs(new_weights - old_weights).sum()
        cost = self.cost * turnover

        # portfolio return
        r = self.returns.iloc[self.t].values
        port_ret = np.dot(new_weights, r) - cost

        self.weights = new_weights
        self.episode_returns.append(port_ret)

        self.t += 1
        if self.t >= len(self.returns):
            self.done = True

        return self._get_state(), port_ret, self.done

    def _get_state(self):
        return self.returns.iloc[self.t - self.window:self.t].values


# ===== Policy Network =====
class PolicyNet(nn.Module):
    def __init__(self, n_assets, window):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(n_assets * window, 128),
            nn.ReLU(),
            nn.Linear(128, n_assets),
            nn.Softmax(dim=-1)  # long-only portfolio weights
        )

    def forward(self, x):
        return self.fc(x)


# ===== Training with Sharpe reward =====
def sharpe_ratio(rets):
    rets = np.array(rets)
    if rets.std() == 0:
        return 0
    return np.sqrt(252) * rets.mean() / rets.std()

def train(env, episodes=200, lr=1e-3):
    policy = PolicyNet(env.n_assets, env.window)
    optimizer = optim.Adam(policy.parameters(), lr=lr)

    for ep in range(episodes):
        log_probs = []
        state = env.reset()
        done = False

        while not done:
            state_t = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
            weights = policy(state_t).squeeze()

            # sample discrete asset for simplicity
            dist = torch.distributions.Categorical(probs=weights)
            action = dist.sample()
            one_hot = torch.nn.functional.one_hot(action, env.n_assets).float().numpy()

            log_probs.append(dist.log_prob(action))
            state, _, done = env.step(one_hot)

        # compute Sharpe of trajectory
        sr = sharpe_ratio(env.episode_returns)

        # REINFORCE update
        loss = -torch.stack(log_probs).sum() * sr
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (ep+1) % 20 == 0:
            print(f"Episode {ep+1}, Sharpe: {sr:.3f}")

    return policy


# ===== Backtest =====
def backtest(env, policy):
    state = env.reset()
    done = False
    port_curve = [1.0]

    while not done:
        state_t = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        weights = policy(state_t).squeeze().detach().numpy()
        state, r, done = env.step(weights)
        port_curve.append(port_curve[-1] * (1 + r))

    port_curve = pd.Series(port_curve, index=env.returns.index[env.window-1:])
    return port_curve

# Fetch data
import yfinance as yf
tickers = [
    "AAPL", "MSFT", "GOOG", "AMZN", "FB", "TSLA", "BRK-A", "JPM", "JNJ", "V",
    "PG", "UNH", "HD", "MA", "VZ", "NVDA", "PYPL", "DIS", "ADBE", "NFLX",
    "CMCSA", "CSCO", "PEP", "KO", "MRK", "PFE", "TM", "BABA", "XOM", "WMT"
]
data = yf.download(tickers, period="max", group_by='column')  # max history
close = data['Close']
returns_temp = close.pct_change()
returns = returns_temp.dropna()
print(returns.shape,returns_temp.shape)

# Train RL agent
env = PortfolioEnv(returns, window=20, cost=0.001)
policy = train(env, episodes=300, lr=1e-3)

# Backtest RL
env_bt = PortfolioEnv(returns, window=20, cost=0.001)
rl_curve = backtest(env_bt, policy)
rl_length = len(rl_curve)

# Baseline: Equal Weight
ew_curve = (returns.iloc[-rl_length:].mean(axis=1) + 1).cumprod()

# Baseline: SMA on one asset (e.g., AAPL)
close_appl = close['AAPL'].dropna()
sma_fast = close_appl.rolling(20).mean()
sma_slow = close_appl.rolling(50).mean()
signal = (sma_fast > sma_slow).astype(int).shift(1).iloc[-rl_length:]
sma_curve = (1 + signal * returns["AAPL"].iloc[-rl_length:]).cumprod()

# Plot comparison
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(rl_curve, label="RL (Sharpe-Optimized)")
plt.plot(ew_curve, label="Equal Weight")
plt.plot(sma_curve, label="SMA (AAPL)")
plt.legend()
plt.title("Backtest: RL vs Baselines")
plt.show()

# Performance stats
def perf_stats(curve):
    rets = curve.pct_change().dropna()
    return {
        "Sharpe": sharpe_ratio(rets),
        "CAGR": (curve.iloc[-1]/curve.iloc[0])**(252/len(curve)) - 1,
        "MaxDD": (curve/curve.cummax() - 1).min()
    }

print("RL", perf_stats(rl_curve))
print("EW", perf_stats(ew_curve))
print("SMA", perf_stats(sma_curve))
# Out:
# /tmp/ipython-input-1636547325.py:131: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, period="max", group_by='column')  # max history
# [*********************100%***********************]  30 of 30 completed
# (41, 30) (16019, 30)
# Episode 20, Sharpe: 2.502
# Episode 40, Sharpe: -4.352
# Episode 60, Sharpe: -6.444
# Episode 80, Sharpe: -0.511
# Episode 100, Sharpe: -3.147
# Episode 120, Sharpe: 1.319
# Episode 140, Sharpe: -1.454
# Episode 160, Sharpe: -5.358
# Episode 180, Sharpe: -1.962
# Episode 200, Sharpe: 3.275
# Episode 220, Sharpe: -2.372
# Episode 240, Sharpe: 1.657
# Episode 260, Sharpe: 0.652
# Episode 280, Sharpe: -9.133
# Episode 300, Sharpe: -4.473
# RL {'Sharpe': np.float64(3.050026805473791), 'CAGR': np.float64(0.36207363064207887), 'MaxDD': -0.031072234471678395}
# EW {'Sharpe': np.float64(2.090821477154857), 'CAGR': np.float64(0.2387871812158191), 'MaxDD': -0.03475180736353811}
# SMA {'Sharpe': np.float64(2.6460758753485085), 'CAGR': np.float64(1.0198206614910266), 'MaxDD': -0.0545199609565431}

# %%
len(rl_curve),len(sma_curve),len(ew_curve)
# Out:
# (22, 11247, 22)

# %%
sma_curve
# Out:
# Date
# 1981-01-12         NaN
# 1981-01-13         NaN
# 1981-01-14         NaN
# 1981-01-15         NaN
# 1981-01-16         NaN
#                 ...
# 2025-08-19    1.079817
# 2025-08-20    1.058507
# 2025-08-21    1.053309
# 2025-08-22    1.066703
# 2025-08-25    1.063893
# Name: AAPL, Length: 11247, dtype: float64

# %%
close_appl
# Out:
# Date
# 1981-01-12      0.108334
# 1981-01-13      0.104480
# 1981-01-14      0.104908
# 1981-01-15      0.107049
# 1981-01-16      0.106193
#                  ...
# 2025-08-19    230.559998
# 2025-08-20    226.009995
# 2025-08-21    224.899994
# 2025-08-22    227.759995
# 2025-08-25    227.160004
# Name: AAPL, Length: 11247, dtype: float64
